# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import colorsys

# %%
df = pd.read_excel("../Dados/Coronavirus Brasil.xlsx")

# %%
df.head()
# Out:
#    regiao estado municipio  coduf  codmun  codRegiaoSaude nomeRegiaoSaude  \
# 0  Brasil    NaN       NaN     76     NaN             NaN             NaN
# 1  Brasil    NaN       NaN     76     NaN             NaN             NaN
# 2  Brasil    NaN       NaN     76     NaN             NaN             NaN
# 3  Brasil    NaN       NaN     76     NaN             NaN             NaN
# 4  Brasil    NaN       NaN     76     NaN             NaN             NaN
#
#          data  semanaEpi populacaoTCU2019  casosAcumulado  casosNovos  \
# 0  2020-02-26          9        210147125               1           0
# 1  2020-02-27          9        210147125               1           0
# 2  2020-02-28          9        210147125               1           0
# 3  2020-02-29          9        210147125               2           1
# 4  2020-03-01         10        210147125               2           0
#
#    obitosAcumulado  obitosNovos  Recuperadosnovos  emAcompanhamentoNovos
# ...

# %%
df.describe()
# Out:
#                coduf         codmun  codRegiaoSaude      semanaEpi  \
# count  151279.000000  148960.000000   148201.000000  151279.000000
# mean       31.216051  313516.904585    31233.354984      19.763794
# std         9.779300   96915.330094     9670.535679       2.420634
# min        11.000000  110000.000000    11001.000000       9.000000
# 25%        24.000000  240870.000000    24005.000000      18.000000
# 50%        31.000000  313460.000000    31037.000000      20.000000
# 75%        41.000000  355730.000000    41001.000000      22.000000
# max        76.000000  530010.000000    53001.000000      23.000000
#
#        casosAcumulado     casosNovos  obitosAcumulado    obitosNovos  \
# count   151279.000000  151279.000000    151279.000000  151279.000000
# mean       211.499977      11.538555        13.264888       0.650817
# std       5102.623331     265.409915       321.507576      14.210504
# min          1.000000       0.000000         0.000000       0.000000
# ...

# %%
list(df)
# Out:
# ['regiao',
#  'estado',
#  'municipio',
#  'coduf',
#  'codmun',
#  'codRegiaoSaude',
#  'nomeRegiaoSaude',
#  'data',
#  'semanaEpi',
#  'populacaoTCU2019',
#  'casosAcumulado',
#  'casosNovos',
#  'obitosAcumulado',
#  'obitosNovos',
#  'Recuperadosnovos',
#  'emAcompanhamentoNovos']

# %%
len(df)
# Out:
# 151279

# %%
len(df[df.estado == 'PI'].municipio.unique())
# Out:
# 165
